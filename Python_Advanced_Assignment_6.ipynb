# %% [markdown]
# <b>Q1. Describe three applications for exception processing.

# %% [markdown]
# - except: embeds the code which is to be executed if an exception is encountered within the try block
# - else: embeds the code to be executed if no exception is occured
# - finally: this block of code is executed irrespective of the occurence of an exception

# %% [markdown]
# <b>Q2. What happens if you don&#39;t do something extra to treat an exception?

# %% [markdown]
# The code execution would be terminated.

# %% [markdown]
# <b>Q3. What are your options for recovering from an exception in your script?

# %% [markdown]
# Embed the code block which you feel may raise an exception into try block and add an except block to handle it so that the code doesn't terminate even after encountering an exception

# %% [markdown]
# <b>Q4. Describe two methods for triggering exceptions in your script.

# %% [markdown]
# raise and assert

# %% [markdown]
# <b>Q5. Identify two methods for specifying actions to be executed at termination time, regardless of
# whether or not an exception exists.

# %% [markdown]
# Adding a finally block that executes irrespective of the occurrence of an exception
